# %%
import pandas as pd                                         #importing the libraries
import numpy as np
import matplotlib.pyplot as plt                                          
import seaborn as sns

# %%
#importing the dataset
sonar_df = pd.read_csv("C:\\Users\\PUNEET SINGH\\SONAR_DATA.csv",header=0,names=range(0,61))
sonar_df.head()                                           #checking the shape of dataset
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#        58      59  60
# 0  0.0052  0.0044   R
# 1  0.0095  0.0078   R
# 2  0.0040  0.0117   R
# ...

# %%
sonar_df.dtypes
# Out:
# 0     float64
# 1     float64
# 2     float64
# 3     float64
# 4     float64
# 5     float64
# 6     float64
# 7     float64
# 8     float64
# 9     float64
# 10    float64
# 11    float64
# 12    float64
# 13    float64
# 14    float64
# 15    float64
# 16    float64
# 17    float64
# 18    float64
# 19    float64
# 20    float64
# 21    float64
# 22    float64
# 23    float64
# 24    float64
# 25    float64
# 26    float64
# 27    float64
# 28    float64
# 29    float64
#        ...
# 31    float64
# 32    float64
# 33    float64
# 34    float64
# 35    float64
# 36    float64
# 37    float64
# 38    float64
# 39    float64
# 40    float64
# 41    float64
# 42    float64
# 43    float64
# 44    float64
# 45    float64
# 46    float64
# 47    float64
# 48    float64
# 49    float64
# 50    float64
# 51    float64
# 52    float64
# 53    float64
# 54    float64
# 55    float64
# 56    float64
# 57    float64
# 58    float64
# 59    float64
# 60     object
# ...

# %%
sonar_df.head()                                       #checking the first five rows of the dataset
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#        58      59  60
# 0  0.0052  0.0044   R
# 1  0.0095  0.0078   R
# 2  0.0040  0.0117   R
# ...

# %%
sonar_df.tail(10)                               #checking the last ten rows of the dataset
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 197  0.0238  0.0318  0.0422  0.0399  0.0788  0.0766  0.0881  0.1143  0.1594
# 198  0.0116  0.0744  0.0367  0.0225  0.0076  0.0545  0.1110  0.1069  0.1708
# 199  0.0131  0.0387  0.0329  0.0078  0.0721  0.1341  0.1626  0.1902  0.2610
# 200  0.0335  0.0258  0.0398  0.0570  0.0529  0.1091  0.1709  0.1684  0.1865
# 201  0.0272  0.0378  0.0488  0.0848  0.1127  0.1103  0.1349  0.2337  0.3113
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#          9   ...      51      52      53      54      55      56      57  \
# ...

# %%
sonar_df.describe()                             #checking the summary of the datset
# Out:
#                0           1           2           3           4           5   \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  207.000000  207.000000  207.000000  207.000000  ...  207.000000
# mean     0.121591    0.134677    0.177361    0.208245  ...    0.016034
# ...

# %%
#checking for missing values
sonar_df.isnull().sum().any()
# Out:
# False

# %%
# checking the correlation between the variables
corr_heatmap = sonar_df.corr()
plt.figure(figsize=(20,18))
sns.heatmap(corr_heatmap)
plt.show()

# %%
#################### univariate analysis#################
sns.distplot(sonar_df[2])
plt.show()                              # checking for normality of the variable

# %%
sns.distplot(sonar_df[6])
plt.show()

# %%
sns.distplot(sonar_df[22])
plt.show()
                                         # checking for normality of the variable
                                         # left skewed data

# %%
######### finding the outliers in the data through boxplot######
plt.boxplot(sonar_df[2])
plt.show()

# %%
plt.boxplot(sonar_df[22])
plt.show()

# %% [markdown]
# # PRINCIPAL COMPONENT ANALYSIS

# %%
########### reduing the number of columns through PRINCIPAL COMPONENT ANALYSIS
# importing the library
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
x = sonar_df.iloc[:,0:-1].values

# %%
x = pca.fit_transform(x)
print(x.shape)
# Out:
# (207, 10)

# %%
sonar_new = pd.DataFrame(x)
type(sonar_new)
print(sonar_new.head())
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.970285  1.017654  0.830432  0.120147  0.299120  0.202682 -0.226988
# 1 -0.324435  0.876876  0.228203  0.868926  0.098053 -0.269122 -0.421778
# 2  0.853571  0.697734 -0.023602 -0.123425 -0.584388  0.351808  0.478187
# 3 -0.061337  0.226034  0.635198  0.152907  0.150982  0.081111 -0.374523
# 4 -0.605423  0.901962  0.804550  0.271896  0.496832  0.464410 -0.224909
#
#           7         8         9
# 0  0.384837  0.004329 -0.082679
# 1  0.081072  0.014185 -0.432334
# 2 -0.215424 -0.533955 -0.425182
# 3  0.070143  0.119454 -0.427480
# 4  0.105504 -0.202842 -0.235048

# %%
sonar_new.describe()
# Out:
#                   0             1             2             3             4  \
# count  2.070000e+02  2.070000e+02  2.070000e+02  2.070000e+02  2.070000e+02
# mean   1.065975e-17  7.776925e-17  3.005178e-17 -6.831626e-17 -5.341607e-17
# std    7.483084e-01  5.979380e-01  3.867577e-01  3.358322e-01  3.007149e-01
# min   -1.400483e+00 -1.149870e+00 -9.271157e-01 -7.043437e-01 -7.021742e-01
# 25%   -5.858327e-01 -4.535057e-01 -2.352042e-01 -2.264010e-01 -2.173866e-01
# 50%    4.991800e-02 -5.663978e-02 -1.530817e-02 -2.208635e-02  7.676589e-03
# 75%    4.910975e-01  3.986697e-01  2.146323e-01  2.109728e-01  1.950131e-01
# max    1.704758e+00  1.483897e+00  1.098007e+00  9.234228e-01  7.933962e-01
#
#                   5             6             7             8             9
# count  2.070000e+02  2.070000e+02  2.070000e+02  2.070000e+02  2.070000e+02
# mean  -3.315249e-17  1.131341e-16  8.336729e-17 -4.069477e-17  6.704245e-17
# ...

# %%
x = sonar_df.iloc[:,0:-1].values                #choosing the independent and dependent variables
y = sonar_df.iloc[:,-1].values

# %%
# splitting the dataset 
# importing the library
from sklearn.model_selection import train_test_split

# %%
#splitting the dataset 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20)

# %%
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (165, 60) (165,) (42, 60) (42,)

# %%
y_train=y_train.reshape(-1,1)

# %%
y_train.shape
# Out:
# (165, 1)

# %%
y_test=y_test.reshape(-1,1)
y_test.shape
# Out:
# (42, 1)

# %%
# creating a logistic regression model
# importing the library
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression(random_state=0,solver='lbfgs')

# %%
classifier.fit(x_train,y_train.ravel())
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
classifier.score(x,y)
# Out:
# 0.8309178743961353

# %%
# prediciting the test result
y_pred = classifier.predict(x_test)
print(y_pred)
# Out:
# ['R' 'M' 'M' 'M' 'M' 'M' 'M' 'M' 'R' 'M' 'M' 'M' 'M' 'R' 'M' 'R' 'R' 'R'
#  'M' 'M' 'M' 'R' 'R' 'M' 'M' 'M' 'R' 'R' 'M' 'M' 'R' 'M' 'M' 'M' 'M' 'M'
#  'R' 'R' 'R' 'R' 'R' 'M']

# %%
# checking for probability and auc-roc curve
var_prob = classifier.predict_proba(x_test)

# %%
# confusion metrics
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[22,  4],
#        [ 4, 12]], dtype=int64)

# %%
# finding the accuracy score
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test,y_pred)
print(score)
############## LOGISTIC MODEL HAS PREDICTED 80% WHICH IS GOOD #############
# Out:
# 0.8095238095238095

# %%
###### knn algorithm model ##############
from sklearn.neighbors import KNeighborsClassifier

# %%
classfier = KNeighborsClassifier( n_neighbors=5,metric='minkowski',p = 2) #creating an object

# %%
classfier.fit(x_train,y_train.ravel())
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
# prediciting the test result
y_pred = classifier.predict(x_test)
print(y_pred)
# Out:
# ['R' 'M' 'M' 'M' 'M' 'M' 'M' 'M' 'R' 'M' 'M' 'M' 'M' 'R' 'M' 'R' 'R' 'R'
#  'M' 'M' 'M' 'R' 'R' 'M' 'M' 'M' 'R' 'R' 'M' 'M' 'R' 'M' 'M' 'M' 'M' 'M'
#  'R' 'R' 'R' 'R' 'R' 'M']

# %%
# confusion metrics
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[22,  4],
#        [ 4, 12]], dtype=int64)

# %%
# finding the accuracy score
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test,y_pred)
print(score)
############## KNN HAS PREDICTED 80% WHICH IS GOOD #############
# Out:
# 0.8095238095238095

# %%
################## support vector machine algorithm ################

# %%
from sklearn.svm import SVC

# %%
classfier=SVC(kernel='linear',random_state=0)
classfier.fit(x_train,y_train.ravel())
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = classfier.predict(x_test)

# %%
# confusion metrics
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[20,  6],
#        [ 5, 11]], dtype=int64)

# %%
############# decision tree classifier#####

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier=DecisionTreeClassifier(criterion="entropy")

# %%
classfier.fit(x_train,y_train.ravel())
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = classfier.predict(x_test)
print(y_pred)
# Out:
# ['R' 'M' 'M' 'M' 'M' 'M' 'M' 'M' 'R' 'M' 'M' 'R' 'M' 'R' 'M' 'M' 'R' 'R'
#  'R' 'M' 'M' 'R' 'R' 'M' 'M' 'M' 'R' 'R' 'M' 'M' 'R' 'M' 'M' 'M' 'M' 'M'
#  'R' 'R' 'R' 'R' 'R' 'M']

# %%
## checking the accuracy score
from sklearn.metrics import accuracy_score

# %%
score = accuracy_score(y_pred,y_test)
score
# Out:
# 0.7380952380952381

# %%
########### Naïve Bayes ###################
# Importing the library
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()
gnb.fit(x_train,y_train)
prediction_y=gnb.predict(x_test)
prediction_y
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array(['R', 'M', 'R', 'M', 'R', 'M', 'M', 'R', 'R', 'R', 'R', 'R', 'M',
#        'R', 'M', 'R', 'R', 'R', 'R', 'R', 'M', 'R', 'R', 'M', 'R', 'R',
#        'R', 'M', 'M', 'R', 'R', 'R', 'R', 'M', 'M', 'R', 'R', 'M', 'R',
#        'R', 'M', 'R'], dtype='<U1')

# %%
score = accuracy_score(prediction_y,y_test)
score
# Out:
# 0.6190476190476191

# %%
# LOGISTIC MODEL AND KNN BOTH ARE PREDICTING THE RESULT WITH 80% ACCURACY WHICH IS VERY GOOD ##########
